# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Sales.xlsx")

# %%
df.head()
# Out:
#    Order ID Order Date   Unit Cost  Price  Order Qty  Cost of Sales   Sales  \
# 0     15000 2023-11-14   10.936943   15.9         20     218.738862   318.0
# 1     14999 2023-01-18  113.237461  279.0         12    1358.849536  3348.0
# 2     14998 2022-08-02  363.634986  588.0         13    4727.254816  7408.8
# 3     14997 2022-01-02   55.387212  999.0         10     553.872121  9990.0
# 4     14996 2021-12-16   16.240455   25.0         12     194.885455   300.0
#
#         Profit Channel                   Promotion Name  \
# 0    99.261138  Online                      No Discount
# 1  1989.150464  Online           Asian Summer Promotion
# 2  2681.545184  Online  North America Holiday Promotion
# 3  9436.127879  Online                      No Discount
# 4   105.114545  Online           Asian Summer Promotion
#
#                                        Product Name          Manufacturer  \
# 0  Contoso USB Wave Multi-media Keyboard E280 Black          Contoso, Ltd
# ...
